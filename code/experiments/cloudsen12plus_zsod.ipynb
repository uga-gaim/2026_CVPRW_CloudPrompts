# %%
from cloudprompts.eval import evaluate_metrics

results = evaluate_metrics(
    gt_dir="../data/cloudsen12plus/export_p509_high_npz/kk",
    pred_dir="../data/cloudsen12plus/export_p509_high_npz/kk",
    model="lseg",
    dataset="cloudsen12p",
    stage="zsod",
    num_classes=4,
    class_names=["clear", "thick-cloud", "thin-cloud", "cloud-shadow"],
)

print("aggregate mIoU:", results["aggregate_miou"])
print("wrote:", results["miou_csv"])
print("wrote:", results["cm_csv"])
print("samples:", results["num_samples"])
# Out:
# aggregate mIoU: 1.0
# wrote: runs/miou_lseg_cloudsen12p_zsod.csv
# wrote: runs/cm_lseg_cloudsen12p_zsod.csv
# samples: 4
# /Users/harshithkethavath/Library/Mobile Documents/com~apple~CloudDocs/University of Georgia/Dr. Weiming Hu/2026_CloudPrompts/code/cloudprompts/eval/seg_eval.py:151: RuntimeWarning: invalid value encountered in divide
#   per_class_iou = np.where(denom > 0, tp / denom, np.nan)
